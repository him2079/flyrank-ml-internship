# %% [markdown]
# <a href="https://colab.research.google.com/github/him2079/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/him2079/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# Lane: Content refresh prioritization. I want to answer which underperforming pages a content team should fix first, and why. This matters because most SEO teams have far more declining pages than time to fix them — the real bottleneck isn't identifying a problem page, it's ranking hundreds of them by which fix will actually move the needle. I picked this lane because it's a resource-allocation problem, not just a detection problem, which felt like the more useful (and harder) question to practice on.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# This work informs a content team's weekly refresh queue: which pages get rewritten or updated this sprint. The person acting on it is a content strategist or SEO lead with limited hours and a long list of declining pages. If the recommendation is wrong — flagging a low-impact page as urgent, or missing a high-impact one — the cost is wasted editorial hours on a page that wouldn't have moved traffic anyway, while a page that actually mattered keeps declining untouched.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %%
# !git clone https://github.com/him2079/flyrank-ml-internship.git
# %cd flyrank-ml-internship
# Out:
# Cloning into 'flyrank-ml-internship'...
# remote: Enumerating objects: 111, done.
# remote: Counting objects: 100% (111/111), done.
# remote: Compressing objects: 100% (66/66), done.
# remote: Total 111 (delta 29), reused 99 (delta 29), pack-reused 0 (from 0)
# Receiving objects: 100% (111/111), 1.82 MiB | 10.51 MiB/s, done.
# Resolving deltas: 100% (29/29), done.
# /content/flyrank-ml-internship/flyrank-ml-internship

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# Out of 30,000 pages in the sample, 54.2% are currently declining (trend_direction == "down"), against smaller stable, up, new, and flat groups. That's a large enough share that a team can't manually triage all of them — which is exactly the resource-allocation problem this lane is meant to help with.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Total pages:", len(df))
print(df["trend_direction"].value_counts())
print("Share declining:", (df["trend_direction"] == "down").mean().round(3))
# Out:
# Total pages: 30000
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64
# Share declining: 0.542

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# This work will produce observed and directional findings — patterns in which page characteristics correlate with decline, and a ranked, decision-support queue for triage. It will not produce causal proof that any specific fix improves rankings, and it will never claim to predict how Google's algorithm behaves. Any queue I generate is a prioritization aid for a human, not an automated verdict.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
